# %% [markdown]
# # Fantasy Premier League Player Goal Analysis

# %% [markdown]
# ### Created by PouncingZebra

# %% [markdown]
# ## Hypothesis
# Picking a fantasy football team requires extensive knowledge of the league's players.  I believe that by looking at statistics from prior matches and the known information about future matches, players can be ranked on how well they can be expected to play.
# My project looks at a focused area within the Premier League, how many goals a player scores.  I wanted to predict how many goals a player can be expected to score.  This information will allow for the creation of the best roster based on goals scored to pick for fantasy football.

# %% [markdown]
# ## Dataset
# The data was extracted from : Fantrax, a Premier League statistics website that keeps track of weekly scores on an immediate basis. Numerous sporting statistics are recorded during each match to see how good players and teams are and to be able to compare one person/team to another.
# The data we haven taken includes the player, their team, position, ranking, and the number of games played this year.  As well, the data has various features on the statistics from the games played.

# %%
import numpy as np # imports a fast numerical programming library
import scipy as sp # imports stats functions, amongst other things
import matplotlib as mpl # this actually imports matplotlib
import matplotlib.cm as cm # allows us easy access to colormaps
import matplotlib.pyplot as plt # sets up plotting under plt
import pandas as pd # lets us handle data as dataframes
import seaborn as sns
import re
import random
import requests

# %matplotlib inline

#BPL = British Premier League

BPLplayerStats1_url = "https://www.fantrax.com/newui/EPL/statsPlayers.go?isSubmit=y&sId=&sortOrder=SCORING_CATEGORY&sortScId=6340&prevPageNumber=1&pageNumber=&season=918&maxResultsPerPage=100&scKind=NON_GOALIE_STANDARD&position=-2"
BPLplayerStats2_url = "https://www.fantrax.com/newui/EPL/statsPlayers.go?isSubmit=y&sId=&sortOrder=SCORING_CATEGORY&sortScId=6340&prevPageNumber=1&pageNumber=2&season=918&maxResultsPerPage=100&scKind=NON_GOALIE_STANDARD&position=-2"
BPLplayerStats3_url = "https://www.fantrax.com/newui/EPL/statsPlayers.go?isSubmit=y&sId=&sortOrder=SCORING_CATEGORY&sortScId=6340&prevPageNumber=2&pageNumber=3&season=918&maxResultsPerPage=100&scKind=NON_GOALIE_STANDARD&position=-2"
BPLplayerStats4_url = "https://www.fantrax.com/newui/EPL/statsPlayers.go?isSubmit=y&sId=&sortOrder=SCORING_CATEGORY&sortScId=6340&prevPageNumber=3&pageNumber=4&season=918&maxResultsPerPage=100&scKind=NON_GOALIE_STANDARD&position=-2"

BPLplayerStats1_table = pd.read_html(BPLplayerStats1_url, encoding='utf-8')
BPLplayerStats2_table = pd.read_html(BPLplayerStats2_url, encoding='utf-8')
BPLplayerStats3_table = pd.read_html(BPLplayerStats3_url, encoding='utf-8')
BPLplayerStats4_table = pd.read_html(BPLplayerStats4_url, encoding='utf-8')

#Player Stats Page 1
playerStats1 = BPLplayerStats1_table[1]
playerStats1_header = playerStats1.iloc[0] 
playerStats1 = playerStats1[1:]
playerStats1.columns = playerStats1_header

#Player Stats Page 2
playerStats2 = BPLplayerStats2_table[1]
playerStats2_header = playerStats2.iloc[0] 
playerStats2 = playerStats2[1:]
playerStats2.columns = playerStats2_header 

#Player Stats Page 3
playerStats3 = BPLplayerStats3_table[1]
playerStats3_header = playerStats3.iloc[0] 
playerStats3 = playerStats3[1:]
playerStats3.columns = playerStats3_header 

#Player Stats Page 4
playerStats4 = BPLplayerStats4_table[1]
playerStats4_header = playerStats4.iloc[0]
playerStats4 = playerStats4[1:] 
playerStats4.columns = playerStats4_header

playerStatsFrames = [playerStats1, playerStats2, playerStats3, playerStats4]
playerStats = pd.concat(playerStatsFrames)
playerStats = playerStats.reset_index(drop=True)

#Splitting players from team
playerTeams = pd.DataFrame(playerStats.Player.str.split(' - ',1).tolist(),
                                   columns = ['Player','Team'])


del playerStats['Player']
stats = pd.merge(playerTeams, playerStats, left_on=playerStats.index, 
                 right_on=playerStats.index, left_index=True, right_index=True)

stats.head()
# Out:
#                        Player  Team Rank Pos  GP  GS   G  A Pts SOT   S Min/G  \
# 0            Sterling, Raheem   MCI    1   F  12  12   8  6  14  16  30  85.5
# 1  Aubameyang, Pierre-Emerick   ARS   T2   F  14  12  10  2  12  13  31  74.0
# 2              Agüero, Sergio   MCI   T2   F  13  13   8  4  12  19  55  74.2
# 3                Hazard, Eden   CHE   T2   F  13  10   7  5  12  16  36  74.1
# 4              Wilson, Callum  BOUR    5   F  14  14   7  4  11  15  35  88.0
#
#    FC  FS YC RC DPt
# 0  16  21  1  0  19
# 1   4  12  0  0   4
# 2   8   8  2  0  14
# 3   4  39  2  0  10
# 4  22  19  3  0  31

# %%
stats.describe()
# Out:
#                    Player Team  Rank  Pos   GP   GS    G    A  Pts  SOT    S  \
# count                 396  396   396  396  396  396  396  396  396  396  396
# unique                396   20    14    3   14   15   10    7   14   22   43
# top     Mustafi, Shkodran  MUN  T225    M   14   14    0    0    0    0    0
# freq                    1   22   172  153   66   50  234  244  172  130   49
#
#        Min/G   FC   FS   YC   RC  DPt
# count    396  396  396  396  396  396
# unique   258   28   34    7    3   40
# top     90.0    1    0    0    0    0
# freq      49   33   41  148  375   26

# %% [raw]
# Player
# Team
# Rank
# Pos     Position (F - Forward, M - Midfield, D - Defense)
# GP      Games Played
# GS      Games Started
# G       Goals
# A       Assists
# Pts     Points
# SOT     Shots on target
# S       Shots
# Min/G   Minutes per game
# FC      Fouls Committed
# FS      Fouls Suffered
# YC      Yellow Cards
# RC      Red Cards
# DPt     Discipline Points

# %% [markdown]
# ## Data Preprocessing
# Since this information is very sought after, the recorded data is accurate and does not have missing values that need to be dealt with.  However, I did need to change the datatypes and calculate a few extra features for our model.  Two features that I found were necessary were shot percentage and total minutes played.

# %%
stats['GP'] = stats['GP'].astype('int')
stats['G'] = stats['G'].astype('int')
stats['A'] = stats['A'].astype('int')
stats['SOT'] = stats['SOT'].astype('int')
stats['S'] = stats['S'].astype('int')
stats['FC'] = stats['FC'].astype('int')
stats['FS'] = stats['FS'].astype('int')
stats['Min/G'] = stats['Min/G'].astype('double')
stats['GP'] = stats['GP'].astype('int')

# %%
#Calculating percentage of shots on target
#SP = Shot Percentage
stats['SP'] = stats['SOT']/stats['S']
# MP = Minutes Played
stats['MP'] = stats['Min/G']*stats['GP']
stats.head(10)
# Out:
#                        Player  Team Rank Pos  GP  GS   G  A Pts  SOT   S  \
# 0            Sterling, Raheem   MCI    1   F  12  12   8  6  14   16  30
# 1  Aubameyang, Pierre-Emerick   ARS   T2   F  14  12  10  2  12   13  31
# 2              Agüero, Sergio   MCI   T2   F  13  13   8  4  12   19  55
# 3                Hazard, Eden   CHE   T2   F  13  10   7  5  12   16  36
# 4              Wilson, Callum  BOUR    5   F  14  14   7  4  11   15  35
# 5               Mohamed Salah   LIV   T6   F  14  14   7  3  10   22  51
# 6                 Sané, Leroy   MCI   T6   F  12   7   5  5  10   10  23
# 7                 Kane, Harry   TOT   T8   F  14  14   8  1   9   25  48
# 8                Fraser, Ryan  BOUR   T8   M  14  14   3  6   9    9  20
# 9           Sigurdsson, Gylfi   EVE  T10   M  14  14   6  2   8   13  35
#
#    Min/G  FC  FS YC RC DPt        SP      MP
# 0   85.5  16  21  1  0  19  0.533333  1026.0
# 1   74.0   4  12  0  0   4  0.419355  1036.0
# 2   74.2   8   8  2  0  14  0.345455   964.6
# 3   74.1   4  39  2  0  10  0.444444   963.3
# 4   88.0  22  19  3  0  31  0.428571  1232.0
# 5   85.3  12  14  0  0  12  0.431373  1194.2
# 6   56.9   1   6  1  0   4  0.434783   682.8
# 7   89.6  17  34  3  0  26  0.520833  1254.4
# 8   84.9   0  23  1  0   3  0.450000  1188.6
# 9   84.4  13  20  2  0  19  0.371429  1181.6

# %% [markdown]
# ## Data Analysis and Visualization

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
cmap = cm.get_cmap('seismic', 90)
cax = ax1.imshow(stats[['MP', 'G', 'A', 'SOT', 'S', 'SP', 'FC', 'FS']].corr(), interpolation="nearest", cmap=cmap)
ax1.grid(True)
plt.title('Player Stats Correlation')
labels=['MP', 'Goals', 'Assists', 'Shots On Target', 'Shots', 'Shot Accuracy','Fouls Committed', 'Fouls Suffered']
ax1.set_xticks(np.arange(len(labels)))
ax1.set_yticks(np.arange(len(labels)))
ax1.set_xticklabels(labels,fontsize=10)
ax1.set_yticklabels(labels,fontsize=10)
# Add colorbar, make sure to specify tick locations to match desired ticklabels
fig.colorbar(cax, ticks=[.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, .75,.8,.85,.90,.95,1])
fig.set_figheight(15)
fig.set_figwidth(15)
plt.show()

# %% [markdown]
# ### With the above Correlation Matrix, we can see which stats are correlated to scoring goals. Obviously, more shots and shots on target mean more goals, but intestingly enough, shots and shots on targets are only 50% correlated to assists- even more intruiging, shot accuracy is barely correlated to goals and almost not correlated to assists at all. This shows that accuracy of shooting has almost no effect on goals/assists; more shots are better than better shots.

# %%
top100 = pd.DataFrame
top100 = stats[0:100].copy()
top100.head()
# Out:
#                        Player  Team Rank Pos  GP  GS   G  A Pts  SOT   S  \
# 0            Sterling, Raheem   MCI    1   F  12  12   8  6  14   16  30
# 1  Aubameyang, Pierre-Emerick   ARS   T2   F  14  12  10  2  12   13  31
# 2              Agüero, Sergio   MCI   T2   F  13  13   8  4  12   19  55
# 3                Hazard, Eden   CHE   T2   F  13  10   7  5  12   16  36
# 4              Wilson, Callum  BOUR    5   F  14  14   7  4  11   15  35
#
#    Min/G  FC  FS YC RC DPt        SP      MP
# 0   85.5  16  21  1  0  19  0.533333  1026.0
# 1   74.0   4  12  0  0   4  0.419355  1036.0
# 2   74.2   8   8  2  0  14  0.345455   964.6
# 3   74.1   4  39  2  0  10  0.444444   963.3
# 4   88.0  22  19  3  0  31  0.428571  1232.0

# %%
#All Players in the BPL
grid = sns.PairGrid(stats, vars=['MP', 'G', 'A', 'S'], hue="Team")
grid.map_diag(sns.kdeplot)
grid.map_offdiag(plt.scatter, s=20)

# %%
#Only Top 100 BPL Players
grid = sns.PairGrid(top100, vars=['MP', 'G', 'A', 'S'], hue="Team")
grid.map_diag(sns.kdeplot)
grid.map_offdiag(plt.scatter, s=20)
# Out:
# C:\Users\caruanacr\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\caruanacr\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# The above grids show that the top100 players are representative of the entire league

# %%
#Goals Histogram
top100.G.hist(bins=100)

# %%
#Goals per Game
top100['GpGP'] = top100['G']/top100['GP']
#Shots per Game
top100['SpGP'] = top100['S']/top100['GP']

top100['GpGP'] = top100['GpGP'].astype('double')
top100['SpGP'] = top100['SpGP'].astype('double')

plt.scatter(top100.SpGP, top100.GpGP)
print("Goals per game vs Shots per Game")
# Out:
# Goals per game vs Shots per Game

# %% [markdown]
# ## Data Modeling and Prediction

# %% [markdown]
# #### Using Training and Validation Sets

# %%
# Import Linear Regression
import sklearn
from sklearn.linear_model import LinearRegression

# %%
# create X and y
feature_cols = ['S', 'SOT', 'GP', 'FS']
X = top100[feature_cols]
y = top100['G']

# follow the usual sklearn pattern: import, instantiate, fit
lm = LinearRegression()
lm.fit(X, y)

# print intercept and coefficients
print (lm.intercept_)
print (lm.coef_)
# Out:
# 0.49554105753827216
# [ 1.64067128e-04  3.29078810e-01 -5.04420901e-02  3.42649991e-02]

# %%
# pair the feature names with the coefficients
for i, j in zip(feature_cols, lm.coef_):
    print(i, j)
# Out:
# S 0.00016406712768656323
# SOT 0.32907880961827307
# GP -0.0504420900716541
# FS 0.03426499910509647

# %% [markdown]
# ### Prediction of Player with given stats

# %%
# predict goals for player with 30 shots, 14 on target, 12 games, 17 fouls suffered
lm.predict([[30, 14, 12, 17]])
# Out:
# array([5.08476631])

# %%
# calculate the R-squared
lm.score(X, y)
# Out:
# 0.6398371511891322

# %%
# Use seaborn to create and plot a linear fit
sns.lmplot('S','G',data = top100)
print ('Linear Model Regression Plot of Shots vs Goals')
# Out:
# Linear Model Regression Plot of Shots vs Goals

# %%
# Create a LinearRegression Object
lreg = LinearRegression()
# Data Columns
X_multi = top100.drop(['GpGP', 'Player', 'Pos', 'Team', 'Rank'], 1)

# Targets
Y_target = top100.GpGP

# Implement Linear Regression
lreg.fit(X_multi,Y_target)
print(' The estimated intercept coefficient is %.2f ' %lreg.intercept_)
print(' The number of coefficients used was %d ' % len(lreg.coef_))
# Out:
#  The estimated intercept coefficient is 0.13
#  The number of coefficients used was 16

# %%
import pandas as pd
from pandas import Series, DataFrame
# Create a DataFrame from the Features
coeff_df = DataFrame(X_multi.columns)
coeff_df.columns = ['Features']

# Add a new column with the coefficients from the linear regression
coeff_df["Coefficient Estimate"] = pd.Series(lreg.coef_)

# Show
print ('Table 1. Multivariate coefficients')
coeff_df
# Out:
# Table 1. Multivariate coefficients
#    Features  Coefficient Estimate
# 0        GP             -0.012797
# 1        GS             -0.001153
# 2         G              0.052937
# 3         A             -0.026592
# 4       Pts              0.026345
# 5       SOT             -0.002974
# 6         S             -0.007945
# 7     Min/G             -0.001411
# 8        FC             -0.000716
# 9        FS             -0.000040
# 10       YC             -0.002736
# 11       RC              0.001597
# 12      DPt              0.000659
# 13       SP              0.060523
# 14       MP              0.000142
# 15     SpGP              0.112346

# %% [markdown]
# With the Coefficient Estimate, it is shown that Shot per Games Played is the strongest correlation to goals per game.

# %%
X = top100.SpGP
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X,top100.G, test_size=0.4, random_state=0)

# Print shapes of the training and testing data sets
print (X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)

# numpy expects matrix with dimension column
X_train = X_train.values.reshape(X_train.shape[0],1)
Y_train = Y_train.values.reshape(Y_train.shape[0],1)
X_test = X_test.values.reshape(X_test.shape[0],1)
Y_test = Y_test.values.reshape(Y_test.shape[0],1)

print (X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (60,) (40,) (60,) (40,)
# (60, 1) (40, 1) (60, 1) (40, 1)

# %%
# Regression object
lreg = LinearRegression()

# Build a linear regression model on the training data only
lreg.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Predictions on training and testing sets
pred_train = lreg.predict(X_train)
pred_test = lreg.predict(X_test)

print ("Fit a model X_train, and calculate MSE with Y_train: %.2f"  % np.mean((Y_train - pred_train) ** 2) ) 
print ("Fit a model X_train, and calculate MSE with X_test and Y_test: %.2f"  % np.mean((Y_test - pred_test) ** 2) )
# Out:
# Fit a model X_train, and calculate MSE with Y_train: 2.68
# Fit a model X_train, and calculate MSE with X_test and Y_test: 2.69

# %%
# Scatter plot the training data
train = plt.scatter(pred_train,(pred_train-Y_train),c='b',alpha=0.5)

# Scatter plot the testing data
test = plt.scatter(pred_test,(pred_test-Y_test),c='r',alpha=0.5)

# Plot a horizontal axis line at 0
plt.hlines(y=0,xmin=0,xmax=8)

#Labels
plt.legend((train,test),('Training','Test'),loc='lower left')
plt.title('Residual Plots')
# Out:
# Text(0.5,1,'Residual Plots')

# %% [markdown]
# Looks like there aren't any major patterns to be concerned about. Overall the majority of the residuals seem to be randomly distributed above and below the horizontal.

# %% [markdown]
# ### Predicting Goals from shots per game

# %%
# Predicting Goals for a player with 3 shots per game
lreg.predict(3)
# Out:
# array([[6.14513032]])

# %%
#Expected Goals
top100['EG'] = top100.apply(lambda row: lreg.predict(row.SpGP), axis=1)
top100['EG'] = top100['EG'].astype('double')
top100.head()
# Out:
#                        Player  Team Rank Pos  GP  GS   G  A Pts  SOT  \
# 0            Sterling, Raheem   MCI    1   F  12  12   8  6  14   16
# 1  Aubameyang, Pierre-Emerick   ARS   T2   F  14  12  10  2  12   13
# 2              Agüero, Sergio   MCI   T2   F  13  13   8  4  12   19
# 3                Hazard, Eden   CHE   T2   F  13  10   7  5  12   16
# 4              Wilson, Callum  BOUR    5   F  14  14   7  4  11   15
#
#      ...     FC  FS  YC  RC DPt        SP      MP      GpGP      SpGP  \
# 0    ...     16  21   1   0  19  0.533333  1026.0  0.666667  2.500000
# 1    ...      4  12   0   0   4  0.419355  1036.0  0.714286  2.214286
# 2    ...      8   8   2   0  14  0.345455   964.6  0.615385  4.230769
# 3    ...      4  39   2   0  10  0.444444   963.3  0.538462  2.769231
# 4    ...     22  19   3   0  31  0.428571  1232.0  0.500000  2.500000
#
#          EG
# 0  5.031729
# 1  4.395500
# 2  8.885809
# 3  5.631253
# 4  5.031729
#
# [5 rows x 22 columns]

# %% [markdown]
# EG, or expected goals, is now set for each individual top 100 player. The value represents how many goals the player should have based on how many shots per game they take. Some players are above their EG (which is good for the player), some are below their EG.

# %% [markdown]
# ### Adding Future Fixture Difficulties into Players
# Different teams have a different difficulty to play against.  This means that players won't play the same and can not be expected to do the same against an easy team compared to a more difficult team.  This fixture takes into the account the difficulty of each players next 5 games.

# %%
#Average fixture difficulty for the next 5 GameWeeks
#stats['Fix_5'] = 0
#Fixture Difficulty for GameWeeks
stats['Fix_GW11'] = 0
stats['Fix_GW12'] = 0
stats['Fix_GW13'] = 0
stats['Fix_GW14'] = 0
stats['Fix_GW15'] = 0
stats['Fix_GW16'] = 0
stats['Fix_GW17'] = 0
stats['Fix_GW18'] = 0


#Arsenal
stats.loc[stats['Team'] == "ARS", 'Fix_GW11'] = 4
stats.loc[stats['Team'] == "ARS", 'Fix_GW12'] = 3
stats.loc[stats['Team'] == "ARS", 'Fix_GW13'] = 3
stats.loc[stats['Team'] == "ARS", 'Fix_GW14'] = 4
stats.loc[stats['Team'] == "ARS", 'Fix_GW15'] = 4
stats.loc[stats['Team'] == "ARS", 'Fix_GW16'] = 2
stats.loc[stats['Team'] == "ARS", 'Fix_GW17'] = 2
stats.loc[stats['Team'] == "ARS", 'Fix_GW18'] = 2

#Bournemouth
stats.loc[stats['Team'] == "BOUR", 'Fix_GW11'] = 4
stats.loc[stats['Team'] == "BOUR", 'Fix_GW12'] = 2
stats.loc[stats['Team'] == "BOUR", 'Fix_GW13'] = 4
stats.loc[stats['Team'] == "BOUR", 'Fix_GW14'] = 5
stats.loc[stats['Team'] == "BOUR", 'Fix_GW15'] = 2
stats.loc[stats['Team'] == "BOUR", 'Fix_GW16'] = 4
stats.loc[stats['Team'] == "BOUR", 'Fix_GW17'] = 3
stats.loc[stats['Team'] == "BOUR", 'Fix_GW18'] = 2


#Brighton
stats.loc[stats['Team'] == "BRIGHT", 'Fix_GW11'] = 3
stats.loc[stats['Team'] == "BRIGHT", 'Fix_GW12'] = 2
stats.loc[stats['Team'] == "BRIGHT", 'Fix_GW13'] = 3
stats.loc[stats['Team'] == "BRIGHT", 'Fix_GW14'] = 2
stats.loc[stats['Team'] == "BRIGHT", 'Fix_GW15'] = 2
stats.loc[stats['Team'] == "BRIGHT", 'Fix_GW16'] = 2
stats.loc[stats['Team'] == "BRIGHT", 'Fix_GW17'] = 4
stats.loc[stats['Team'] == "BRIGHT", 'Fix_GW18'] = 3

#Burnley
stats.loc[stats['Team'] == "BURN", 'Fix_GW11'] = 3
stats.loc[stats['Team'] == "BURN", 'Fix_GW12'] = 3
stats.loc[stats['Team'] == "BURN", 'Fix_GW13'] = 2
stats.loc[stats['Team'] == "BURN", 'Fix_GW14'] = 2
stats.loc[stats['Team'] == "BURN", 'Fix_GW15'] = 4
stats.loc[stats['Team'] == "BURN", 'Fix_GW16'] = 2
stats.loc[stats['Team'] == "BURN", 'Fix_GW17'] = 4
stats.loc[stats['Team'] == "BURN", 'Fix_GW18'] = 4

#Cardiff
stats.loc[stats['Team'] == "CAR", 'Fix_GW11'] = 3
stats.loc[stats['Team'] == "CAR", 'Fix_GW12'] = 2
stats.loc[stats['Team'] == "CAR", 'Fix_GW13'] = 3
stats.loc[stats['Team'] == "CAR", 'Fix_GW14'] = 3
stats.loc[stats['Team'] == "CAR", 'Fix_GW15'] = 3
stats.loc[stats['Team'] == "CAR", 'Fix_GW16'] = 2
stats.loc[stats['Team'] == "CAR", 'Fix_GW17'] = 3
stats.loc[stats['Team'] == "CAR", 'Fix_GW18'] = 4

#Chelsea
stats.loc[stats['Team'] == "CHE", 'Fix_GW11'] = 2
stats.loc[stats['Team'] == "CHE", 'Fix_GW12'] = 3
stats.loc[stats['Team'] == "CHE", 'Fix_GW13'] = 4
stats.loc[stats['Team'] == "CHE", 'Fix_GW14'] = 2
stats.loc[stats['Team'] == "CHE", 'Fix_GW15'] = 3
stats.loc[stats['Team'] == "CHE", 'Fix_GW16'] = 5
stats.loc[stats['Team'] == "CHE", 'Fix_GW17'] = 3
stats.loc[stats['Team'] == "CHE", 'Fix_GW18'] = 3

#Crystal Palace
stats.loc[stats['Team'] == "CRY", 'Fix_GW11'] = 4
stats.loc[stats['Team'] == "CRY", 'Fix_GW12'] = 4
stats.loc[stats['Team'] == "CRY", 'Fix_GW13'] = 4
stats.loc[stats['Team'] == "CRY", 'Fix_GW14'] = 2
stats.loc[stats['Team'] == "CRY", 'Fix_GW15'] = 3
stats.loc[stats['Team'] == "CRY", 'Fix_GW16'] = 3
stats.loc[stats['Team'] == "CRY", 'Fix_GW17'] = 3
stats.loc[stats['Team'] == "CRY", 'Fix_GW18'] = 5

#Everton
stats.loc[stats['Team'] == "EVE", 'Fix_GW11'] = 2
stats.loc[stats['Team'] == "EVE", 'Fix_GW12'] = 4
stats.loc[stats['Team'] == "EVE", 'Fix_GW13'] = 2
stats.loc[stats['Team'] == "EVE", 'Fix_GW14'] = 5
stats.loc[stats['Team'] == "EVE", 'Fix_GW15'] = 2
stats.loc[stats['Team'] == "EVE", 'Fix_GW16'] = 3
stats.loc[stats['Team'] == "EVE", 'Fix_GW17'] = 5
stats.loc[stats['Team'] == "EVE", 'Fix_GW18'] = 4

#Fulham
stats.loc[stats['Team'] == "FUL", 'Fix_GW11'] = 2
stats.loc[stats['Team'] == "FUL", 'Fix_GW12'] = 5
stats.loc[stats['Team'] == "FUL", 'Fix_GW13'] = 2
stats.loc[stats['Team'] == "FUL", 'Fix_GW14'] = 4
stats.loc[stats['Team'] == "FUL", 'Fix_GW15'] = 3
stats.loc[stats['Team'] == "FUL", 'Fix_GW16'] = 4
stats.loc[stats['Team'] == "FUL", 'Fix_GW17'] = 2
stats.loc[stats['Team'] == "FUL", 'Fix_GW18'] = 2

#Huddersfield
stats.loc[stats['Team'] == "HUD", 'Fix_GW11'] = 2
stats.loc[stats['Team'] == "HUD", 'Fix_GW12'] = 2
stats.loc[stats['Team'] == "HUD", 'Fix_GW13'] = 3
stats.loc[stats['Team'] == "HUD", 'Fix_GW14'] = 2
stats.loc[stats['Team'] == "HUD", 'Fix_GW15'] = 3
stats.loc[stats['Team'] == "HUD", 'Fix_GW16'] = 4
stats.loc[stats['Team'] == "HUD", 'Fix_GW17'] = 2
stats.loc[stats['Team'] == "HUD", 'Fix_GW18'] = 2

#Leicester
stats.loc[stats['Team'] == "LEIC", 'Fix_GW11'] = 2
stats.loc[stats['Team'] == "LEIC", 'Fix_GW12'] = 2
stats.loc[stats['Team'] == "LEIC", 'Fix_GW13'] = 3
stats.loc[stats['Team'] == "LEIC", 'Fix_GW14'] = 3
stats.loc[stats['Team'] == "LEIC", 'Fix_GW15'] = 2
stats.loc[stats['Team'] == "LEIC", 'Fix_GW16'] = 4
stats.loc[stats['Team'] == "LEIC", 'Fix_GW17'] = 2
stats.loc[stats['Team'] == "LEIC", 'Fix_GW18'] = 4

#Liverpool
stats.loc[stats['Team'] == "LIV", 'Fix_GW11'] = 4
stats.loc[stats['Team'] == "LIV", 'Fix_GW12'] = 2
stats.loc[stats['Team'] == "LIV", 'Fix_GW13'] = 3
stats.loc[stats['Team'] == "LIV", 'Fix_GW14'] = 3
stats.loc[stats['Team'] == "LIV", 'Fix_GW15'] = 2
stats.loc[stats['Team'] == "LIV", 'Fix_GW16'] = 3
stats.loc[stats['Team'] == "LIV", 'Fix_GW17'] = 4
stats.loc[stats['Team'] == "LIV", 'Fix_GW18'] = 3

#Manchester City
stats.loc[stats['Team'] == "MCI", 'Fix_GW11'] = 2
stats.loc[stats['Team'] == "MCI", 'Fix_GW12'] = 4
stats.loc[stats['Team'] == "MCI", 'Fix_GW13'] = 3
stats.loc[stats['Team'] == "MCI", 'Fix_GW14'] = 3
stats.loc[stats['Team'] == "MCI", 'Fix_GW15'] = 3
stats.loc[stats['Team'] == "MCI", 'Fix_GW16'] = 4
stats.loc[stats['Team'] == "MCI", 'Fix_GW17'] = 3
stats.loc[stats['Team'] == "MCI", 'Fix_GW18'] = 2

#Manchester United
stats.loc[stats['Team'] == "MUN", 'Fix_GW11'] = 3
stats.loc[stats['Team'] == "MUN", 'Fix_GW12'] = 5
stats.loc[stats['Team'] == "MUN", 'Fix_GW13'] = 2
stats.loc[stats['Team'] == "MUN", 'Fix_GW14'] = 2
stats.loc[stats['Team'] == "MUN", 'Fix_GW15'] = 4
stats.loc[stats['Team'] == "MUN", 'Fix_GW16'] = 2
stats.loc[stats['Team'] == "MUN", 'Fix_GW17'] = 5
stats.loc[stats['Team'] == "MUN", 'Fix_GW18'] = 2

#Newcastle
stats.loc[stats['Team'] == "NEW", 'Fix_GW11'] = 3
stats.loc[stats['Team'] == "NEW", 'Fix_GW12'] = 3
stats.loc[stats['Team'] == "NEW", 'Fix_GW13'] = 2
stats.loc[stats['Team'] == "NEW", 'Fix_GW14'] = 2
stats.loc[stats['Team'] == "NEW", 'Fix_GW15'] = 3
stats.loc[stats['Team'] == "NEW", 'Fix_GW16'] = 3
stats.loc[stats['Team'] == "NEW", 'Fix_GW17'] = 2
stats.loc[stats['Team'] == "NEW", 'Fix_GW18'] = 2

#Southampton
stats.loc[stats['Team'] == "SOU", 'Fix_GW11'] = 5
stats.loc[stats['Team'] == "SOU", 'Fix_GW12'] = 3
stats.loc[stats['Team'] == "SOU", 'Fix_GW13'] = 2
stats.loc[stats['Team'] == "SOU", 'Fix_GW14'] = 4
stats.loc[stats['Team'] == "SOU", 'Fix_GW15'] = 4
stats.loc[stats['Team'] == "SOU", 'Fix_GW16'] = 2
stats.loc[stats['Team'] == "SOU", 'Fix_GW17'] = 4
stats.loc[stats['Team'] == "SOU", 'Fix_GW18'] = 2

#Spurs
stats.loc[stats['Team'] == "TOT", 'Fix_GW11'] = 3
stats.loc[stats['Team'] == "TOT", 'Fix_GW12'] = 2
stats.loc[stats['Team'] == "TOT", 'Fix_GW13'] = 4
stats.loc[stats['Team'] == "TOT", 'Fix_GW14'] = 4
stats.loc[stats['Team'] == "TOT", 'Fix_GW15'] = 2
stats.loc[stats['Team'] == "TOT", 'Fix_GW16'] = 3
stats.loc[stats['Team'] == "TOT", 'Fix_GW17'] = 2
stats.loc[stats['Team'] == "TOT", 'Fix_GW18'] = 3

#Watford
stats.loc[stats['Team'] == "WAT", 'Fix_GW11'] = 2
stats.loc[stats['Team'] == "WAT", 'Fix_GW12'] = 2
stats.loc[stats['Team'] == "WAT", 'Fix_GW13'] = 4
stats.loc[stats['Team'] == "WAT", 'Fix_GW14'] = 3
stats.loc[stats['Team'] == "WAT", 'Fix_GW15'] = 5
stats.loc[stats['Team'] == "WAT", 'Fix_GW16'] = 3
stats.loc[stats['Team'] == "WAT", 'Fix_GW17'] = 2
stats.loc[stats['Team'] == "WAT", 'Fix_GW18'] = 3

#West Ham
stats.loc[stats['Team'] == "WHU", 'Fix_GW11'] = 2
stats.loc[stats['Team'] == "WHU", 'Fix_GW12'] = 2
stats.loc[stats['Team'] == "WHU", 'Fix_GW13'] = 5
stats.loc[stats['Team'] == "WHU", 'Fix_GW14'] = 2
stats.loc[stats['Team'] == "WHU", 'Fix_GW15'] = 2
stats.loc[stats['Team'] == "WHU", 'Fix_GW16'] = 3
stats.loc[stats['Team'] == "WHU", 'Fix_GW17'] = 3
stats.loc[stats['Team'] == "WHU", 'Fix_GW18'] = 2

#Wolves
stats.loc[stats['Team'] == "WOLVES", 'Fix_GW11'] = 4
stats.loc[stats['Team'] == "WOLVES", 'Fix_GW12'] = 4
stats.loc[stats['Team'] == "WOLVES", 'Fix_GW13'] = 2
stats.loc[stats['Team'] == "WOLVES", 'Fix_GW14'] = 2
stats.loc[stats['Team'] == "WOLVES", 'Fix_GW15'] = 4
stats.loc[stats['Team'] == "WOLVES", 'Fix_GW16'] = 3
stats.loc[stats['Team'] == "WOLVES", 'Fix_GW17'] = 2
stats.loc[stats['Team'] == "WOLVES", 'Fix_GW18'] = 4

# %%
#Average fixture difficulty for the next 5 GameWeeks
#top100['Fix_5'] = stats['Fix_5'].copy()
#Fixture Difficulty for GameWeeks
top100['Fix_GW11'] = stats['Fix_GW11'].copy()
top100['Fix_GW12'] = stats['Fix_GW12'].copy()
top100['Fix_GW13'] = stats['Fix_GW13'].copy()
top100['Fix_GW14'] = stats['Fix_GW14'].copy()
top100['Fix_GW15'] = stats['Fix_GW15'].copy()
top100['Fix_GW16'] = stats['Fix_GW16'].copy()
top100['Fix_GW17'] = stats['Fix_GW17'].copy()
top100['Fix_GW18'] = stats['Fix_GW18'].copy()

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(top100)
# Out:
#                         Player    Team Rank Pos  GP  GS   G  A Pts  SOT   S  \
# 0             Sterling, Raheem     MCI    1   F  12  12   8  6  14   16  30
# 1   Aubameyang, Pierre-Emerick     ARS   T2   F  14  12  10  2  12   13  31
# 2               Agüero, Sergio     MCI   T2   F  13  13   8  4  12   19  55
# 3                 Hazard, Eden     CHE   T2   F  13  10   7  5  12   16  36
# 4               Wilson, Callum    BOUR    5   F  14  14   7  4  11   15  35
# 5                Mohamed Salah     LIV   T6   F  14  14   7  3  10   22  51
# 6                  Sané, Leroy     MCI   T6   F  12   7   5  5  10   10  23
# 7                  Kane, Harry     TOT   T8   F  14  14   8  1   9   25  48
# 8                 Fraser, Ryan    BOUR   T8   M  14  14   3  6   9    9  20
# 9            Sigurdsson, Gylfi     EVE  T10   M  14  14   6  2   8   13  35
# 10        Mitrovic, Aleksandar     FUL  T10   F  14  14   7  1   8   17  48
# 11        Lacazette, Alexandre     ARS  T10   F  13   9   6  2   8   12  30
# 12                Silva, David     MCI  T13   M  12  11   5  2   7   11  26
# 13               Murray, Glenn  BRIGHT  T13   F  14  12   7  0   7    9  17
# 14              Bernardo Silva     MCI  T13   M  13  12   4  3   7    7  22
# 15                 Mané, Sadio     LIV  T13   F  13  13   6  1   7   16  33
# 16           Arnautovic, Marko     WHU  T13   F  12  12   5  2   7   16  34
# 17               Ramsey, Aaron     ARS  T13   M  14   6   1  6   7    8  13
# 18               Jiménez, Raúl  WOLVES  T13   F  14  14   3  4   7   17  43
# 19             Maddison, James    LEIC  T20   M  13  13   4  2   6   10  25
# 20               Barkley, Ross     CHE  T20   M  12   5   3  3   6    5  16
# 21            Martial, Anthony     MUN  T20   F  11   8   6  0   6   10  16
# 22                       Pedro     CHE  T20   F  12   7   5  1   6   10  23
# 23             Felipe Anderson     WHU  T20   M  14  14   5  1   6   11  19
# 24          Johann Gudmundsson    BURN  T20   M  12  12   2  4   6    5  17
# 25                 Richarlison     EVE  T20   F  12  12   6  0   6   13  26
# 26               Holebas, José     WAT  T20   D  11  11   2  4   6    2   6
# 27                Vardy, Jamie    LEIC  T20   F  12   9   5  1   6   14  26
# 28                 Pogba, Paul     MUN  T20   M  13  13   3  3   6   21  40
# 29                King, Joshua    BOUR  T20   F  11  11   5  1   6    7  20
# 30             Roberto Firmino     LIV  T31   F  14  13   3  2   5   10  26
# 31                Lamela, Erik     TOT  T31   M   9   4   4  1   5    8  15
# 32              Lukaku, Romelu     MUN  T31   F  13  10   5  0   5   12  23
# 33            Pereyra, Roberto     WAT  T31   M  14  14   5  0   5   10  25
# 34                 Solly March  BRIGHT  T31   M  14  13   0  5   5    0  15
# 35              Morata, Álvaro     CHE  T31   F  13   9   5  0   5   14  30
# 36          Eriksen, Christian     TOT  T31   M  11   8   0  5   5    6  20
# 37            Rashford, Marcus     MUN  T31   F  11   6   2  3   5    4   9
# 38               Mahrez, Riyad     MCI  T31   M  13   6   4  1   5   11  24
# 39          Knockaert, Anthony  BRIGHT  T31   M  12  10   1  4   5    6  17
# 40             Schürrle, André     FUL  T31   M  13  12   5  0   5   14  38
# 41             Gündogan, Ilkay     MCI  T31   M   9   6   3  2   5    6  15
# 42             Mendy, Benjamin     MCI  T31   D   9   9   0  5   5    2   6
# 43                  Danny Ings     SOU  T31   F  11  10   4  1   5   13  32
# 44             Giroud, Olivier     CHE  T31   F  11   5   1  4   5    7  20
# 45               Milner, James     LIV  T46   M  13   9   2  2   4    3   7
# 46              Alonso, Marcos     CHE  T46   D  14  14   1  3   4    4  23
# 47                 Lucas Moura     TOT  T46   M  13  12   4  0   4    7  18
# 48                Duffy, Shane  BRIGHT  T46   D  14  14   3  1   4    6  11
# 49               Doherty, Matt  WOLVES  T46   D  14  14   2  2   4   10  20
# 50                 Özil, Mesut     ARS  T46   M  10  10   3  1   4    3   5
# 51         Doucouré, Abdoulaye     WAT  T46   M  14  14   0  4   4    3  16
# 52            Shaqiri, Xherdan     LIV  T46   F  10   5   2  2   4    4  14
# 53                     Willian     CHE  T46   F  13  11   2  2   4    7  22
# 54               Walcott, Theo     EVE  T46   F  14  14   2  2   4   11  21
# 55               Brooks, David    BOUR  T46   M  13  12   3  1   4   10  23
# 56              Ryan Sessegnon     FUL  T46   M  14  12   1  3   4    6  12
# 57          Iheanacho, Kelechi    LEIC  T46   F  13   7   1  3   4    4  12
# 58             Vietto, Luciano     FUL  T46   F  10   7   0  4   4    3  11
# 59                 Tosun, Cenk     EVE  T46   F  11   5   2  2   4    9  19
# 60              Zaha, Wilfried     CRY  T46   F  12  12   3  1   4    9  29
# 61            Bellerín, Héctor     ARS  T46   D  14  14   0  4   4    4  15
# 62            Trippier, Kieran     TOT  T46   D  11  11   1  3   4    1   3
# 63                Deeney, Troy     WAT  T64   F  11   9   2  1   3   11  19
# 64                 Gray, Andre     WAT  T64   F  14   8   3  0   3    8  18
# 65               Cédric Soares     SOU  T64   D  14  14   1  2   3    3   8
# 66                  Vokes, Sam    BURN  T64   F  14   9   3  0   3    7  21
# 67             Rondón, Salomón     NEW  T64   F   9   7   2  1   3    5  22
# 68           Armstrong, Stuart     SOU  T64   M  10   4   3  0   3    6   8
# 69             Capoue, Etienne     WAT  T64   M  13  13   1  2   3    2  10
# 70               Gray, Demarai    LEIC  T64   M  11   9   2  1   3    6  16
# 71         Mkhitaryan, Henrikh     ARS  T64   M  11   8   2  1   3    5  23
# 72                 Iwobi, Alex     ARS  T64   M  11   8   1  2   3    5  13
# 73                   Sol Bamba     CAR  T64   D  13  13   2  1   3    4  14
# 74            Paterson, Callum     CAR  T64   D  12   9   3  0   3    7  22
# 75           Robertson, Andrew     LIV  T64   D  13  13   0  3   3    2   6
# 76              Morrison, Sean     CAR  T64   D  14  14   0  3   3    2  13
# 77             Sánchez, Alexis     MUN  T64   F  10   5   1  2   3    7  13
# 78                 Fernandinho     MCI  T64   M  14  14   1  2   3    5  17
# 79          Seri, Jean Michael     FUL  T64   M  14  13   1  2   3    3   7
# 80                 Rúben Neves  WOLVES  T64   M  14  14   2  1   3    7  39
# 81            Albrighton, Marc    LEIC  T64   M  13   7   1  2   3    4  12
# 82            Townsend, Andros     CRY  T64   M  14  14   2  1   3    9  25
# 83                   Dele Alli     TOT  T64   M   9   7   2  1   3    8  14
# 84              Keane, Michael     EVE  T64   D  12  12   1  2   3    6  20
# 85                  Chicharito     WHU  T64   F  10   3   3  0   3    7  14
# 86               Xhaka, Granit     ARS  T64   M  14  14   2  1   3    6  13
# 87               Kanté, N'Golo     CHE  T64   M  14  14   1  2   3    2  14
# 88     Alexander-Arnold, Trent     LIV  T64   D  12  12   1  2   3    4  14
# 89             Yedlin, DeAndre     NEW  T90   D  13  13   1  1   2    2   5
# 90               Gabriel Jesus     MCI  T90   F  11   3   1  1   2   11  18
# 91             Torreira, Lucas     ARS  T90   M  14   9   1  1   2    3  12
# 92           Sturridge, Daniel     LIV  T90   F   8   1   2  0   2    4   9
# 93              Francis, Simon    BOUR  T90   D  13   9   0  2   2    1   2
# 94            Tarkowski, James    BURN  T90   D  11  11   2  0   2    2   5
# 95                  Dier, Eric     TOT  T90   M  11  11   2  0   2    2   4
# 96              Monreal, Nacho     ARS  T90   D   7   7   1  1   2    4   6
# 97               Lennon, Aaron    BURN  T90   M  13  13   1  1   2    2   4
# 98                      Joselu     NEW  T90   F  11   4   2  0   2    5  15
# 99               Ritchie, Matt     NEW  T90   M  13  13   0  2   2    3  15
#
#     Min/G  FC  FS YC RC DPt        SP      MP      GpGP      SpGP        EG  \
# 0    85.5  16  21  1  0  19  0.533333  1026.0  0.666667  2.500000  5.031729
# 1    74.0   4  12  0  0   4  0.419355  1036.0  0.714286  2.214286  4.395500
# 2    74.2   8   8  2  0  14  0.345455   964.6  0.615385  4.230769  8.885809
# 3    74.1   4  39  2  0  10  0.444444   963.3  0.538462  2.769231  5.631253
# 4    88.0  22  19  3  0  31  0.428571  1232.0  0.500000  2.500000  5.031729
# 5    85.3  12  14  0  0  12  0.431373  1194.2  0.500000  3.642857  7.576646
# 6    56.9   1   6  1  0   4  0.434783   682.8  0.416667  1.916667  3.732762
# 7    89.6  17  34  3  0  26  0.520833  1254.4  0.571429  3.428571  7.099474
# 8    84.9   0  23  1  0   3  0.450000  1188.6  0.214286  1.428571  2.645870
# 9    84.4  13  20  2  0  19  0.371429  1181.6  0.428571  2.500000  5.031729
# 10   89.7  20  23  4  0  32  0.354167  1255.8  0.500000  3.428571  7.099474
# 11   72.4  20  20  1  0  23  0.400000   941.2  0.461538  2.307692  4.603498
# 12   78.3   9  12  1  0  12  0.423077   939.6  0.416667  2.166667  4.289462
# 13   71.8  44  26  2  0  50  0.529412  1005.2  0.500000  1.214286  2.168699
# 14   80.7  10  13  2  0  16  0.318182  1049.1  0.307692  1.692308  3.233159
# 15   88.6  16  20  1  0  19  0.484848  1151.8  0.461538  2.538462  5.117376
# 16   81.0  14   7  2  0  20  0.470588   972.0  0.416667  2.833333  5.773997
# 17   43.5   9   5  0  0   9  0.615385   609.0  0.071429  0.928571  1.532469
# 18   83.1  18  11  0  0  18  0.395349  1163.4  0.214286  3.071429  6.304188
# 19   77.8   9  30  1  1  18  0.400000  1011.4  0.307692  1.923077  3.747036
# 20   41.3   8  12  0  0   8  0.312500   495.6  0.250000  1.333333  2.433794
# 21   65.8   7  10  1  0  10  0.625000   723.8  0.545455  1.454545  2.703709
# 22   52.4   7  10  0  0   7  0.434783   628.8  0.416667  1.916667  3.732762
# 23   82.2  12  22  3  0  21  0.578947  1150.8  0.357143  1.357143  2.486813
# 24   81.8   5  11  2  0  11  0.294118   981.6  0.166667  1.416667  2.619361
# 25   85.0  11  35  1  1  20  0.500000  1020.0  0.500000  2.166667  4.289462
# 26   89.5  13   7  6  0  31  0.333333   984.5  0.181818  0.545455  0.679344
# 27   70.8   6   7  0  1  12  0.538462   849.6  0.416667  2.166667  4.289462
# 28   86.2  25  30  2  0  31  0.525000  1120.6  0.230769  3.076923  6.316423
# 29   86.3  17  13  1  0  20  0.350000   949.3  0.454545  1.818182  3.513455
# 30   77.9  19   3  0  0  19  0.384615  1090.6  0.214286  1.857143  3.600214
# 31   48.7  12  13  0  0  12  0.533333   438.3  0.444444  1.666667  3.176061
# 32   75.2   8   2  1  0  11  0.521739   977.6  0.384615  1.769231  3.404451
# 33   84.4  11  20  1  0  14  0.400000  1181.6  0.357143  1.785714  3.441157
# 34   72.6  13  10  0  0  13  0.000000  1016.4  0.000000  1.071429  1.850584
# 35   59.5  15  13  3  0  24  0.466667   773.5  0.384615  2.307692  4.603498
# 36   69.2   5   7  0  0   5  0.300000   761.2  0.000000  1.818182  3.513455
# 37   53.3   8  14  2  1  20  0.444444   586.3  0.181818  0.818182  1.286654
# 38   44.7   6   7  0  0   6  0.458333   581.1  0.307692  1.846154  3.575744
# 39   73.1   8  12  3  0  17  0.352941   877.2  0.083333  1.416667  2.619361
# 40   78.5  13  14  2  0  19  0.368421  1020.5  0.384615  2.923077  5.973838
# 41   58.8   3   7  0  0   3  0.400000   529.2  0.333333  1.666667  3.176061
# 42   90.0  10   2  1  0  13  0.333333   810.0  0.000000  0.666667  0.949259
# 43   75.1   8  12  1  0  11  0.406250   826.1  0.363636  2.909091  5.942694
# 44   42.5   9   4  0  0   9  0.350000   467.5  0.090909  1.818182  3.513455
# 45   61.4  13  12  2  0  19  0.428571   798.2  0.153846  0.538462  0.663772
# 46   89.1   7  20  1  0  10  0.173913  1247.4  0.071429  1.642857  3.123042
# 47   78.3  17  19  2  0  23  0.388889  1017.9  0.307692  1.384615  2.547989
# 48   90.0  11   6  3  0  20  0.545455  1260.0  0.214286  0.785714  1.214355
# 49   87.2  12   5  1  0  15  0.500000  1220.8  0.142857  1.428571  2.645870
# 50   82.5   4  12  1  0   7  0.600000   825.0  0.300000  0.500000  0.578126
# 51   90.0  14   5  2  0  20  0.187500  1260.0  0.000000  1.142857  2.009641
# 52   45.1   5   6  1  0   8  0.285714   451.0  0.200000  1.400000  2.582247
# 53   65.7   8  11  1  0  11  0.318182   854.1  0.153846  1.692308  3.233159
# 54   80.1   4  12  0  0   4  0.523810  1121.4  0.142857  1.500000  2.804928
# 55   70.1   9  22  1  0  12  0.434783   911.3  0.230769  1.769231  3.404451
# 56   75.1   5  10  0  0   5  0.500000  1051.4  0.071429  0.857143  1.373412
# 57   49.8  12   6  1  0  15  0.333333   647.4  0.076923  0.923077  1.520234
# 58   55.4   5  13  1  0   8  0.272727   554.0  0.000000  1.100000  1.914207
# 59   47.2   5   8  1  0   8  0.473684   519.2  0.181818  1.727273  3.311019
# 60   89.9  17  37  3  0  26  0.310345  1078.8  0.250000  2.416667  4.846163
# 61   86.8  13   5  2  0  19  0.266667  1215.2  0.000000  1.071429  1.850584
# 62   82.7   9  11  1  0  12  0.333333   909.7  0.090909  0.272727  0.072035
# 63   81.2  17  14  1  0  20  0.578947   893.2  0.181818  1.727273  3.311019
# 64   50.4   6   8  1  0   9  0.444444   705.6  0.214286  1.285714  2.327756
# 65   87.6   8   6  4  0  20  0.375000  1226.4  0.071429  0.571429  0.737183
# 66   57.4  13   8  0  0  13  0.333333   803.6  0.214286  1.500000  2.804928
# 67   63.7   7   9  1  0  10  0.227273   573.3  0.222222  2.444444  4.908018
# 68   39.7   8   4  1  0  11  0.750000   397.0  0.300000  0.800000  1.246166
# 69   89.9  20  16  5  1  41  0.200000  1168.7  0.076923  0.769231  1.177649
# 70   68.2   6   7  1  0   9  0.375000   750.2  0.181818  1.454545  2.703709
# 71   60.0   9   3  0  0   9  0.217391   660.0  0.181818  2.090909  4.120765
# 72   55.4   4   2  0  0   4  0.384615   609.4  0.090909  1.181818  2.096400
# 73   90.0  17   4  1  0  20  0.285714  1170.0  0.153846  1.076923  1.862819
# 74   73.0  16  17  2  0  22  0.318182   876.0  0.250000  1.833333  3.547195
# 75   90.0   5   5  0  0   5  0.333333  1170.0  0.000000  0.461538  0.492480
# 76   88.6  12  11  1  0  15  0.153846  1240.4  0.000000  0.928571  1.532469
# 77   47.8  11  11  2  0  17  0.538462   478.0  0.100000  1.300000  2.359567
# 78   88.1  20   9  2  0  26  0.294118  1233.4  0.071429  1.214286  2.168699
# 79   77.5  12  15  0  0  12  0.428571  1085.0  0.071429  0.500000  0.578126
# 80   90.0  21   9  5  0  36  0.179487  1260.0  0.142857  2.785714  5.667959
# 81   51.8   5   6  2  0  11  0.333333   673.4  0.076923  0.923077  1.520234
# 82   87.4   5  18  1  0   8  0.360000  1223.6  0.142857  1.785714  3.441157
# 83   70.4   9  11  1  0  12  0.571429   633.6  0.222222  1.555556  2.928639
# 84   89.9   5   4  0  0   5  0.300000  1078.8  0.083333  1.666667  3.176061
# 85   43.4   1  14  0  0   1  0.500000   434.0  0.300000  1.400000  2.582247
# 86   85.4  23  25  5  0  38  0.461538  1195.6  0.142857  0.928571  1.532469
# 87   90.0  12   5  3  0  21  0.142857  1260.0  0.071429  1.000000  1.691527
# 88   89.8  12   5  3  0  21  0.285714  1077.6  0.083333  1.166667  2.062660
# 89   89.2  17   7  2  0  23  0.400000  1159.6  0.076923  0.384615  0.321187
# 90   34.7   4   7  0  0   4  0.611111   381.7  0.090909  1.636364  3.108582
# 91   68.8  16  31  3  0  25  0.250000   963.2  0.071429  0.857143  1.373412
# 92   18.5   2   5  1  0   5  0.444444   148.0  0.250000  1.125000  1.969877
# 93   70.2  10   5  0  0  10  0.500000   912.6  0.000000  0.153846 -0.192690
# 94   84.3  10  12  3  0  19  0.400000   927.3  0.181818  0.454545  0.476908
# 95   85.5  17   6  2  0  23  0.500000   940.5  0.181818  0.363636  0.274471
# 96   90.0   8   9  1  0  11  0.666667   630.0  0.142857  0.857143  1.373412
# 97   83.8   9  16  1  0  12  0.500000  1089.4  0.076923  0.307692  0.149895
# 98   42.5   3   6  1  0   6  0.333333   467.5  0.181818  1.363636  2.501273
# 99   78.8  24  18  5  0  39  0.200000  1024.4  0.000000  1.153846  2.034112
#
#     Fix_GW11  Fix_GW12  Fix_GW13  Fix_GW14  Fix_GW15  Fix_GW16  Fix_GW17  \
# 0          2         4         3         3         3         4         3
# 1          4         3         3         4         4         2         2
# 2          2         4         3         3         3         4         3
# 3          2         3         4         2         3         5         3
# 4          4         2         4         5         2         4         3
# 5          4         2         3         3         2         3         4
# 6          2         4         3         3         3         4         3
# 7          3         2         4         4         2         3         2
# 8          4         2         4         5         2         4         3
# 9          2         4         2         5         2         3         5
# 10         2         5         2         4         3         4         2
# 11         4         3         3         4         4         2         2
# 12         2         4         3         3         3         4         3
# 13         3         2         3         2         2         2         4
# 14         2         4         3         3         3         4         3
# 15         4         2         3         3         2         3         4
# 16         2         2         5         2         2         3         3
# 17         4         3         3         4         4         2         2
# 18         4         4         2         2         4         3         2
# 19         2         2         3         3         2         4         2
# 20         2         3         4         2         3         5         3
# 21         3         5         2         2         4         2         5
# 22         2         3         4         2         3         5         3
# 23         2         2         5         2         2         3         3
# 24         3         3         2         2         4         2         4
# 25         2         4         2         5         2         3         5
# 26         2         2         4         3         5         3         2
# 27         2         2         3         3         2         4         2
# 28         3         5         2         2         4         2         5
# 29         4         2         4         5         2         4         3
# 30         4         2         3         3         2         3         4
# 31         3         2         4         4         2         3         2
# 32         3         5         2         2         4         2         5
# 33         2         2         4         3         5         3         2
# 34         3         2         3         2         2         2         4
# 35         2         3         4         2         3         5         3
# 36         3         2         4         4         2         3         2
# 37         3         5         2         2         4         2         5
# 38         2         4         3         3         3         4         3
# 39         3         2         3         2         2         2         4
# 40         2         5         2         4         3         4         2
# 41         2         4         3         3         3         4         3
# 42         2         4         3         3         3         4         3
# 43         5         3         2         4         4         2         4
# 44         2         3         4         2         3         5         3
# 45         4         2         3         3         2         3         4
# 46         2         3         4         2         3         5         3
# 47         3         2         4         4         2         3         2
# 48         3         2         3         2         2         2         4
# 49         4         4         2         2         4         3         2
# 50         4         3         3         4         4         2         2
# 51         2         2         4         3         5         3         2
# 52         4         2         3         3         2         3         4
# 53         2         3         4         2         3         5         3
# 54         2         4         2         5         2         3         5
# 55         4         2         4         5         2         4         3
# 56         2         5         2         4         3         4         2
# 57         2         2         3         3         2         4         2
# 58         2         5         2         4         3         4         2
# 59         2         4         2         5         2         3         5
# 60         4         4         4         2         3         3         3
# 61         4         3         3         4         4         2         2
# 62         3         2         4         4         2         3         2
# 63         2         2         4         3         5         3         2
# 64         2         2         4         3         5         3         2
# 65         5         3         2         4         4         2         4
# 66         3         3         2         2         4         2         4
# 67         3         3         2         2         3         3         2
# 68         5         3         2         4         4         2         4
# 69         2         2         4         3         5         3         2
# 70         2         2         3         3         2         4         2
# 71         4         3         3         4         4         2         2
# 72         4         3         3         4         4         2         2
# 73         3         2         3         3         3         2         3
# 74         3         2         3         3         3         2         3
# 75         4         2         3         3         2         3         4
# 76         3         2         3         3         3         2         3
# 77         3         5         2         2         4         2         5
# 78         2         4         3         3         3         4         3
# 79         2         5         2         4         3         4         2
# 80         4         4         2         2         4         3         2
# 81         2         2         3         3         2         4         2
# 82         4         4         4         2         3         3         3
# 83         3         2         4         4         2         3         2
# 84         2         4         2         5         2         3         5
# 85         2         2         5         2         2         3         3
# 86         4         3         3         4         4         2         2
# 87         2         3         4         2         3         5         3
# 88         4         2         3         3         2         3         4
# 89         3         3         2         2         3         3         2
# 90         2         4         3         3         3         4         3
# 91         4         3         3         4         4         2         2
# 92         4         2         3         3         2         3         4
# 93         4         2         4         5         2         4         3
# 94         3         3         2         2         4         2         4
# 95         3         2         4         4         2         3         2
# 96         4         3         3         4         4         2         2
# 97         3         3         2         2         4         2         4
# 98         3         3         2         2         3         3         2
# 99         3         3         2         2         3         3         2
#
#     Fix_GW18
# 0          2
# 1          2
# 2          2
# 3          3
# 4          2
# 5          3
# 6          2
# 7          3
# 8          2
# 9          4
# 10         2
# 11         2
# 12         2
# 13         3
# 14         2
# 15         3
# 16         2
# 17         2
# 18         4
# 19         4
# 20         3
# 21         2
# 22         3
# 23         2
# 24         4
# 25         4
# 26         3
# 27         4
# 28         2
# 29         2
# 30         3
# 31         3
# 32         2
# 33         3
# 34         3
# 35         3
# 36         3
# 37         2
# 38         2
# 39         3
# 40         2
# 41         2
# 42         2
# 43         2
# 44         3
# 45         3
# 46         3
# 47         3
# 48         3
# 49         4
# 50         2
# 51         3
# 52         3
# 53         3
# 54         4
# 55         2
# 56         2
# 57         4
# 58         2
# 59         4
# 60         5
# 61         2
# 62         3
# 63         3
# 64         3
# 65         2
# 66         4
# 67         2
# 68         2
# 69         3
# 70         4
# 71         2
# 72         2
# 73         4
# 74         4
# 75         3
# 76         4
# 77         2
# 78         2
# 79         2
# 80         4
# 81         4
# 82         5
# 83         3
# 84         4
# 85         2
# 86         2
# 87         3
# 88         3
# 89         2
# 90         2
# 91         2
# 92         3
# 93         2
# 94         4
# 95         3
# 96         2
# 97         4
# 98         2
# 99         2

# %%
# Gaccuracy is a players accuracy for the goal. It's their total goals minus expected goals to see if they
# are overperforming or underperforming based on shots made.
top100['Gaccuracy'] = top100['G']-top100['EG']
# To determine player worth in the next 3 weeks, the average difficulty of their next 3 fixtures divided by ten was
# normalized at 1 and multiplied by their accuracy for goal prediction made earlier.
top100['PlayerWorth'] = top100['Gaccuracy'] * (1.3-((top100.Fix_GW15) + top100.Fix_GW16 + top100.Fix_GW17)/30)
worth= pd.DataFrame 
worth = top100.copy()
worth = worth.sort_values(['PlayerWorth'], ascending=False)
worth.head(40)
# Out:
#                         Player    Team Rank Pos  GP  GS   G  A Pts  SOT  \
# 1   Aubameyang, Pierre-Emerick     ARS   T2   F  14  12  10  2  12   13
# 13               Murray, Glenn  BRIGHT  T13   F  14  12   7  0   7    9
# 21            Martial, Anthony     MUN  T20   F  11   8   6  0   6   10
# 0             Sterling, Raheem     MCI    1   F  12  12   8  6  14   16
# 23             Felipe Anderson     WHU  T20   M  14  14   5  1   6   11
# 50                 Özil, Mesut     ARS  T46   M  10  10   3  1   4    3
# 4               Wilson, Callum    BOUR    5   F  14  14   7  4  11   15
# 48                Duffy, Shane  BRIGHT  T46   D  14  14   3  1   4    6
# 95                  Dier, Eric     TOT  T90   M  11  11   2  0   2    2
# 68           Armstrong, Stuart     SOU  T64   M  10   4   3  0   3    6
# 25                 Richarlison     EVE  T20   F  12  12   6  0   6   13
# 47                 Lucas Moura     TOT  T46   M  13  12   4  0   4    7
# 33            Pereyra, Roberto     WAT  T31   M  14  14   5  0   5   10
# 32              Lukaku, Romelu     MUN  T31   F  13  10   5  0   5   12
# 29                King, Joshua    BOUR  T20   F  11  11   5  1   6    7
# 94            Tarkowski, James    BURN  T90   D  11  11   2  0   2    2
# 11        Lacazette, Alexandre     ARS  T10   F  13   9   6  2   8   12
# 45               Milner, James     LIV  T46   M  13   9   2  2   4    3
# 3                 Hazard, Eden     CHE   T2   F  13  10   7  5  12   16
# 26               Holebas, José     WAT  T20   D  11  11   2  4   6    2
# 6                  Sané, Leroy     MCI   T6   F  12   7   5  5  10   10
# 22                       Pedro     CHE  T20   F  12   7   5  1   6   10
# 62            Trippier, Kieran     TOT  T46   D  11  11   1  3   4    1
# 7                  Kane, Harry     TOT   T8   F  14  14   8  1   9   25
# 9            Sigurdsson, Gylfi     EVE  T10   M  14  14   6  2   8   13
# 15                 Mané, Sadio     LIV  T13   F  13  13   6  1   7   16
# 31                Lamela, Erik     TOT  T31   M   9   4   4  1   5    8
# 97               Lennon, Aaron    BURN  T90   M  13  13   1  1   2    2
# 14              Bernardo Silva     MCI  T13   M  13  12   4  3   7    7
# 27                Vardy, Jamie    LEIC  T20   F  12   9   5  1   6   14
# 89             Yedlin, DeAndre     NEW  T90   D  13  13   1  1   2    2
# 12                Silva, David     MCI  T13   M  12  11   5  2   7   11
# 37            Rashford, Marcus     MUN  T31   F  11   6   2  3   5    4
# 64                 Gray, Andre     WAT  T64   F  14   8   3  0   3    8
# 20               Barkley, Ross     CHE  T20   M  12   5   3  3   6    5
# 86               Xhaka, Granit     ARS  T64   M  14  14   2  1   3    6
# 85                  Chicharito     WHU  T64   F  10   3   3  0   3    7
# 79          Seri, Jean Michael     FUL  T64   M  14  13   1  2   3    3
# 38               Mahrez, Riyad     MCI  T31   M  13   6   4  1   5   11
# 35              Morata, Álvaro     CHE  T31   F  13   9   5  0   5   14
#
#        ...       Fix_GW11  Fix_GW12  Fix_GW13  Fix_GW14 Fix_GW15 Fix_GW16  \
# 1      ...              4         3         3         4        4        2
# 13     ...              3         2         3         2        2        2
# 21     ...              3         5         2         2        4        2
# 0      ...              2         4         3         3        3        4
# 23     ...              2         2         5         2        2        3
# 50     ...              4         3         3         4        4        2
# 4      ...              4         2         4         5        2        4
# 48     ...              3         2         3         2        2        2
# 95     ...              3         2         4         4        2        3
# 68     ...              5         3         2         4        4        2
# 25     ...              2         4         2         5        2        3
# 47     ...              3         2         4         4        2        3
# 33     ...              2         2         4         3        5        3
# 32     ...              3         5         2         2        4        2
# 29     ...              4         2         4         5        2        4
# 94     ...              3         3         2         2        4        2
# 11     ...              4         3         3         4        4        2
# 45     ...              4         2         3         3        2        3
# 3      ...              2         3         4         2        3        5
# 26     ...              2         2         4         3        5        3
# 6      ...              2         4         3         3        3        4
# 22     ...              2         3         4         2        3        5
# 62     ...              3         2         4         4        2        3
# 7      ...              3         2         4         4        2        3
# 9      ...              2         4         2         5        2        3
# 15     ...              4         2         3         3        2        3
# 31     ...              3         2         4         4        2        3
# 97     ...              3         3         2         2        4        2
# 14     ...              2         4         3         3        3        4
# 27     ...              2         2         3         3        2        4
# 89     ...              3         3         2         2        3        3
# 12     ...              2         4         3         3        3        4
# 37     ...              3         5         2         2        4        2
# 64     ...              2         2         4         3        5        3
# 20     ...              2         3         4         2        3        5
# 86     ...              4         3         3         4        4        2
# 85     ...              2         2         5         2        2        3
# 79     ...              2         5         2         4        3        4
# 38     ...              2         4         3         3        3        4
# 35     ...              2         3         4         2        3        5
#
#    Fix_GW17  Fix_GW18  Gaccuracy  PlayerWorth
# 1         2         2   5.604500     5.791316
# 13        4         3   4.831301     4.992345
# 21        5         2   3.296291     3.076538
# 0         3         2   2.968271     2.869328
# 23        3         2   2.513187     2.596960
# 50        2         2   2.421874     2.502603
# 4         3         2   1.968271     1.968271
# 48        4         3   1.785645     1.845167
# 95        2         3   1.725529     1.840564
# 68        4         2   1.753834     1.695372
# 25        5         4   1.710538     1.653520
# 47        2         3   1.452011     1.548812
# 33        2         3   1.558843     1.506882
# 32        5         2   1.595549     1.489179
# 29        3         2   1.486545     1.486545
# 94        4         4   1.523092     1.472323
# 11        2         2   1.396502     1.443052
# 45        4         3   1.336228     1.336228
# 3         3         3   1.368747     1.277497
# 26        2         3   1.320656     1.276634
# 6         3         2   1.267238     1.224997
# 22        3         3   1.267238     1.182756
# 62        2         3   0.927965     0.989830
# 7         2         3   0.900526     0.960561
# 9         5         4   0.968271     0.935995
# 15        4         3   0.882624     0.882624
# 31        2         3   0.823939     0.878868
# 97        4         4   0.850105     0.821768
# 14        3         2   0.766841     0.741280
# 27        2         4   0.710538     0.734222
# 89        2         2   0.678813     0.701440
# 12        3         2   0.710538     0.686853
# 37        5         2   0.713346     0.665790
# 64        2         3   0.672244     0.649836
# 20        3         3   0.566206     0.528459
# 86        2         2   0.467531     0.483115
# 85        3         2   0.417753     0.431678
# 79        2         2   0.421874     0.421874
# 38        3         2   0.424256     0.410114
# 35        3         3   0.396502     0.370068
#
# [40 rows x 32 columns]
